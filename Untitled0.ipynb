# %%
# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 60000 train samples
# 10000 test samples

# %%
imshow(np.reshape(x_train[70],(28,28)))

# %%
np.shape(y_train[70])
# Out:
# ()

# %%
print(y_train[70])
# Out:
# 1

# %%
# convert class vectors to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Dense(20, activation=LeakyReLU(), input_shape=(784,)))
model.add(Dense(20, activation=LeakyReLU()))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                15700
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# =================================================================
# Total params: 16,330
# Trainable params: 16,330
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
batch_size = 1248

num_classes = 10
epochs = 10
history = model.fit(x_train, y_train,
                                      batch_size=batch_size,
                                      epochs=epochs,
                                      verbose=1,
                                      validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 49/49 [==============================] - 0s 7ms/step - loss: 1.3448 - accuracy: 0.6555 - val_loss: 0.7695 - val_accuracy: 0.8274
# Epoch 2/10
# 49/49 [==============================] - 0s 4ms/step - loss: 0.5827 - accuracy: 0.8594 - val_loss: 0.4369 - val_accuracy: 0.8841
# Epoch 3/10
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4005 - accuracy: 0.8916 - val_loss: 0.3542 - val_accuracy: 0.8999
# Epoch 4/10
# 49/49 [==============================] - 0s 4ms/step - loss: 0.3351 - accuracy: 0.9057 - val_loss: 0.3160 - val_accuracy: 0.9085
# Epoch 5/10
# 49/49 [==============================] - 0s 5ms/step - loss: 0.3038 - accuracy: 0.9139 - val_loss: 0.2993 - val_accuracy: 0.9143
# Epoch 6/10
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2862 - accuracy: 0.9180 - val_loss: 0.2916 - val_accuracy: 0.9154
# Epoch 7/10
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2729 - accuracy: 0.9222 - val_loss: 0.2800 - val_accuracy: 0.9208
# Epoch 8/10
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2632 - accuracy: 0.9247 - val_loss: 0.2668 - val_accuracy: 0.9227
# Epoch 9/10
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2543 - accuracy: 0.9272 - val_loss: 0.2659 - val_accuracy: 0.9247
# Epoch 10/10
# 49/49 [==============================] - 0s 5ms/step - loss: 0.2473 - accuracy: 0.9284 - val_loss: 0.2550 - val_accuracy: 0.9263
